# %%
import numpy as np

# %%
# Single Number Value 
scaler = 5.0
print (scaler)
print(type(scaler))
# Out:
# 5.0
# <class 'float'>

# %%
# 1d Data or Multiple Number of value in a Single bracket 
vector = np.array(
    [1,2,3,4,5]
)
print(vector)
# Out:
# [1 2 3 4 5]

# %%
# 2d Data or Data with rows and column 
mat = np.array(
    [
    [1,2,3,4,5],
    [2,3,4,5,6]
    ]
)
print(type(mat))
print(mat)
print(mat.shape)
# Out:
# <class 'numpy.ndarray'>
# [[1 2 3 4 5]
#  [2 3 4 5 6]]
# (2, 5)
